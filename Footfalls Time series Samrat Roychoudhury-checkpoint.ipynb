# %% [markdown]
# ### <span style = 'color:blue'> TimeSeries</span>
# #### <span style = 'color:blue'>Use any forecasting method to predict Footfalls from the given dataset  </span>

# %% [markdown]
# For Data set please click here <a href="https://drive.google.com/file/d/1zlhACuGnjEuQCuv1Znk2yh1zcbS1wXDs/view?usp=sharing" title="Google Drive">Click here</a>

# %% [markdown]
# The given data is about Footfaals and we have 158 rows and here we have foot falls from 1709 to 2132
# here we have time interval as months
# predict the data using any forecasting method for next 10 footfalls values
#
# **data should 70% for training and 30% testing**
#
# **Expected results**
#
# - **check for dicky fuller test, rolling mean and stationarity**
# - **obtain scores and interpret it**
# - **predict the data or plot the graph that can plot predicted data with actual data**

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('footfalls.csv')

# %% [markdown]
# # View the data and perform statistical analysis

# %%
df.sample(5)
# Out:
#       Month  Footfalls    t  log_footfalls  t_square  Jan  Feb  Mar  Apr  May  \
# 116  Sep-00       1824  117       7.508787     13689    0    0    0    0    0
# 7    Aug-91       2013    8       7.607381        64    0    0    0    0    0
# 115  Aug-00       2097  116       7.648263     13456    0    0    0    0    0
# 74   Mar-97       1708   75       7.443078      5625    0    0    1    0    0
# 149  Jun-03       2130  150       7.663877     22500    0    0    0    0    0
#
#      Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 116    0    0    0    1    0    0    0
# 7      0    0    1    0    0    0    0
# 115    0    0    1    0    0    0    0
# 74     0    0    0    0    0    0    0
# 149    1    0    0    0    0    0    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          159 non-null    object
#  1   Footfalls      159 non-null    int64
#  2   t              159 non-null    int64
#  3   log_footfalls  159 non-null    float64
#  4   t_square       159 non-null    int64
#  5   Jan            159 non-null    int64
#  6   Feb            159 non-null    int64
#  7   Mar            159 non-null    int64
#  8   Apr            159 non-null    int64
#  9   May            159 non-null    int64
#  10  Jun            159 non-null    int64
#  11  Jul            159 non-null    int64
#  12  Aug            159 non-null    int64
#  13  Sep            159 non-null    int64
#  14  Oct            159 non-null    int64
#  15  Nov            159 non-null    int64
#  16  Dec            159 non-null    int64
# dtypes: float64(1), int64(15), object(1)
# memory usage: 21.2+ KB

# %% [markdown]
# # Convert the 'Month' column to datetime format

# %%
df['Month'] = pd.to_datetime(df['Month'], format='%b-%y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          159 non-null    datetime64[ns]
#  1   Footfalls      159 non-null    int64
#  2   t              159 non-null    int64
#  3   log_footfalls  159 non-null    float64
#  4   t_square       159 non-null    int64
#  5   Jan            159 non-null    int64
#  6   Feb            159 non-null    int64
#  7   Mar            159 non-null    int64
#  8   Apr            159 non-null    int64
#  9   May            159 non-null    int64
#  10  Jun            159 non-null    int64
#  11  Jul            159 non-null    int64
#  12  Aug            159 non-null    int64
#  13  Sep            159 non-null    int64
#  14  Oct            159 non-null    int64
#  15  Nov            159 non-null    int64
#  16  Dec            159 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(15)
# memory usage: 21.2 KB

# %%
df.describe()
# Out:
#                                Month    Footfalls           t  log_footfalls  \
# count                            159   159.000000  159.000000     159.000000
# mean   1997-07-31 23:14:43.018867968  1822.226415   80.000000       7.502746
# min              1991-01-01 00:00:00  1361.000000    1.000000       7.215975
# 25%              1994-04-16 00:00:00  1698.500000   40.500000       7.437500
# 50%              1997-08-01 00:00:00  1831.000000   80.000000       7.512618
# 75%              2000-11-16 00:00:00  1967.000000  119.500000       7.584265
# max              2004-03-01 00:00:00  2223.000000  159.000000       7.706613
# std                              NaN   181.601732   46.043458       0.101775
#
#            t_square         Jan         Feb         Mar         Apr  \
# count    159.000000  159.000000  159.000000  159.000000  159.000000
# mean    8506.666667    0.088050    0.088050    0.088050    0.081761
# min        1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     1640.500000    0.000000    0.000000    0.000000    0.000000
# 50%     6400.000000    0.000000    0.000000    0.000000    0.000000
# 75%    14280.500000    0.000000    0.000000    0.000000    0.000000
# max    25281.000000    1.000000    1.000000    1.000000    1.000000
# std     7605.556039    0.284263    0.284263    0.284263    0.274866
#
#               May         Jun         Jul         Aug         Sep         Oct  \
# count  159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.081761    0.081761    0.081761    0.081761    0.081761    0.081761
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# std      0.274866    0.274866    0.274866    0.274866    0.274866    0.274866
#
#               Nov         Dec
# count  159.000000  159.000000
# mean     0.081761    0.081761
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    0.000000
# max      1.000000    1.000000
# std      0.274866    0.274866

# %% [markdown]
# # Indexing setup

# %%
df.set_index('Month', inplace=True)
df.index.freq = 'MS'

# %% [markdown]
# # Plot the original data

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Footfalls'])
plt.title('Original Data')
plt.xlabel('Time')
plt.ylabel('Footfalls')
plt.show()

# %% [markdown]
# # Check for stationarity using the Augmented Dickey-Fuller (ADF) test

# %%
result = adfuller(df['Footfalls'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')

for key, value in result[4].items():
    print(key, value)
# Out:
# ADF Statistic: -0.23499112877866932
# p-value: 0.9342202042969283
# Critical Values:
# 1% -3.476597917537401
# 5% -2.8818291230495543
# 10% -2.5775887982253085

# %% [markdown]
# # Decision criteria

# %%
if result[1] < 0.05:
    print("Decision: The series is stationary.")
else:
    print("Decision: The series is non-stationary.")
# Out:
# Decision: The series is non-stationary.

# %% [markdown]
# # Perform Seasonal decomposition

# %%
decomposition = seasonal_decompose(df['Footfalls'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,8))
plt.subplot(411)
plt.plot(df['Footfalls'], label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Perform moving averages detrending on log_footfalls column to achive stationarity

# %%
window_size = 12
log_footfalls=df['log_footfalls']
log_footfalls_ma = log_footfalls.rolling(window=window_size).mean()
log_footfalls_detrended = log_footfalls - log_footfalls_ma

# %% [markdown]
# # Plot the Moving average

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index, log_footfalls)
plt.plot(df.index, log_footfalls_ma)
plt.title('Moving Average')
plt.xlabel('Time')
plt.ylabel('log_footfalls')
plt.show()

# %% [markdown]
# # Perform the ADF test again to confirm stationarity

# %%
result = adfuller(log_footfalls_detrended.dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')
for key, value in result[4].items():
    print(key, value)
# Out:
# ADF Statistic: -2.8771952772212543
# p-value: 0.048064870144484774
# Critical Values:
# 1% -3.480500383888377
# 5% -2.8835279559405045
# 10% -2.578495716547007

# %% [markdown]
# # Decision criteria

# %%
if result[1] < 0.05:
    print("Decision: The series is stationary.")
else:
    print("Decision: The series is non-stationary.")
# Out:
# Decision: The series is stationary.

# %% [markdown]
# # Split the data into training and testing sets

# %%
train, test = train_test_split(log_footfalls_detrended, test_size=0.3, random_state=42, shuffle=False)

# %% [markdown]
# # Build a SARIMA model

# %%
model = SARIMAX(train, order=(1,1,1), seasonal_order=(1,1,1,12))
model_fit = model.fit()

# %% [markdown]
# # Print the summary of the model

# %%
print(model_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      log_footfalls   No. Observations:                  111
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                  82.736
# Date:                            Tue, 21 Jan 2025   AIC                           -155.471
# Time:                                    20:00:12   BIC                           -142.546
# Sample:                                01-01-1991   HQIC                          -150.243
#                                      - 03-01-2000
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4881      0.105      4.667      0.000       0.283       0.693
# ma.L1         -0.9473      0.073    -13.033      0.000      -1.090      -0.805
# ar.S.L12       0.3184      0.258      1.233      0.218      -0.188       0.825
# ma.S.L12      -0.9782      2.246     -0.436      0.663      -5.379       3.423
# sigma2         0.0010      0.002      0.479      0.632      -0.003       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.02
# Prob(Q):                              0.69   Prob(JB):                         0.99
# Heteroskedasticity (H):               0.76   Skew:                            -0.00
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Define a scoring function

# %%
def score_model(model_fit):
    score = 0
    
    if model_fit.aic < 1000:
        score += 1
    
    if model_fit.bic < 1000:
        score += 1
    
    if model_fit.llf > 0: #(score of log-likelihood)
        score += 1
    
    return score

# %% [markdown]
# # Score the model

# %%
score = score_model(model_fit)
print('Model Score:', score)
# Out:
# Model Score: 3

# %% [markdown]
# # Predicted values

# %%
# Predicted values
predicted_values = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)

# %% [markdown]
# # Plot the actual and predicted values

# %%
plt.figure(figsize=(10,6))
plt.plot(test.index, test.values, label='Actual', color='b')
plt.plot(test.index, predicted_values.values, label='Predicted', color='r')
plt.title('Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Get the forecast for the next 10 footfalls

# %%
forecast = model_fit.get_forecast(steps=10)

# %% [markdown]
# # Create a date range for the forecast period

# %%
forecast_index = pd.date_range(start=df.index[-1] + pd.DateOffset(months=1), periods=10, freq='MS')

# %% [markdown]
# # Plot the forecasted values with confidence intervals

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index, df['Footfalls'], label='Actual')
plt.plot(forecast_index, np.exp(forecast.predicted_mean + df['log_footfalls'].mean()), label='Forecast', marker='o', markerfacecolor='green', markeredgecolor='b',color='r')
plt.plot(forecast_index, np.exp(forecast.predicted_mean - 1.96 * forecast.se_mean + df['log_footfalls'].mean()), label='95% Confidence Interval Lower', linestyle=':', color='g')
plt.plot(forecast_index, np.exp(forecast.predicted_mean + 1.96 * forecast.se_mean + df['log_footfalls'].mean()), label='95% Confidence Interval Upper', linestyle=':', color='g')
plt.fill_between(forecast_index,
np.exp(forecast.predicted_mean - 1.96 * forecast.se_mean + df['log_footfalls'].mean()),
np.exp(forecast.predicted_mean + 1.96 * forecast.se_mean + df['log_footfalls'].mean()),
color='Teal', alpha=0.5)
plt.axvline(x=df.index[-1], color='black', linestyle='--', label='Forecast Start')
plt.legend()
plt.show()

# %% [markdown]
# # Create a pandas Dataframe with the forecasted values and the corresponding dates

# %%
forecast_df = pd.DataFrame({
    'Date': forecast_index,
    'Footfalls': np.exp(forecast.predicted_mean + df['log_footfalls'].mean())
})


forecast_df.reset_index(drop=True, inplace=True)
forecast_df.index += 1

print(forecast_df)
# Out:
#          Date    Footfalls
# 1  2004-04-01  1917.287485
# 2  2004-05-01  1915.989021
# 3  2004-06-01  1876.215210
# 4  2004-07-01  2000.446408
# 5  2004-08-01  2027.108280
# 6  2004-09-01  1690.883267
# 7  2004-10-01  1842.020451
# 8  2004-11-01  1852.404258
# 9  2004-12-01  1864.312207
# 10 2005-01-01  1602.096839

# %% [markdown]
# # Calculate metrics

# %%
# Actual values
actual = test.values

# Predicted values
predicted = model_fit.predict(start=len(train), end=len(train)+len(test)-1)

# Calculate MAE
mae = np.mean(np.abs(actual - predicted))
print("MAE:", mae)

# Calculate MSE
mse = np.mean((actual - predicted)**2)
print("MSE:", mse)

# Calculate RMSE
rmse = np.sqrt(mse)
print("RMSE:", rmse)

# Calculate R-squared
r2 = 1 - (np.sum((actual - predicted)**2) / np.sum((actual - np.mean(actual))**2))
print("R-squared:", r2)
# Out:
# MAE: 0.024660681330702653
# MSE: 0.0009721998300723508
# RMSE: 0.031180119147821594
# R-squared: 0.8341091834240248
